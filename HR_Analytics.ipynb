# %% [markdown]
# # HR_Analytics Use Case:-

# %% [markdown]
# ## Data Description:-

# %% [markdown]
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# # Importing Libraries:-

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the Data:-

# %%
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null object
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# Over18                      1470 non-null object
# OverTime                    1470 non-null object
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(26), object(9)
# memory usage: 402.0+ KB

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# top     Research & Development               NaN          NaN  Life Sciences
# freq                       961               NaN          NaN            606
# mean                       NaN          9.192517     2.912925            NaN
# std                        NaN          8.106864     1.024165            NaN
# min                        NaN          1.000000     1.000000            NaN
# 25%                        NaN          2.000000     2.000000            NaN
# 50%                        NaN          7.000000     3.000000            NaN
# 75%                        NaN         14.000000     4.000000            NaN
# max                        NaN         29.000000     5.000000            NaN
#
#         EmployeeCount  EmployeeNumber          ...           \
# count          1470.0     1470.000000          ...
# unique            NaN             NaN          ...
# top               NaN             NaN          ...
# freq              NaN             NaN          ...
# mean              1.0     1024.865306          ...
# std               0.0      602.024335          ...
# min               1.0        1.000000          ...
# 25%               1.0      491.250000          ...
# 50%               1.0     1020.500000          ...
# 75%               1.0     1555.750000          ...
# max               1.0     2068.000000          ...
#
#         RelationshipSatisfaction StandardHours  StockOptionLevel  \
# count                1470.000000        1470.0       1470.000000
# unique                       NaN           NaN               NaN
# top                          NaN           NaN               NaN
# freq                         NaN           NaN               NaN
# mean                    2.712245          80.0          0.793878
# std                     1.081209           0.0          0.852077
# min                     1.000000          80.0          0.000000
# 25%                     2.000000          80.0          0.000000
# 50%                     3.000000          80.0          1.000000
# 75%                     4.000000          80.0          1.000000
# max                     4.000000          80.0          3.000000
#
#         TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# count         1470.000000            1470.000000     1470.000000
# unique                NaN                    NaN             NaN
# top                   NaN                    NaN             NaN
# freq                  NaN                    NaN             NaN
# mean            11.279592               2.799320        2.761224
# std              7.780782               1.289271        0.706476
# min              0.000000               0.000000        1.000000
# 25%              6.000000               2.000000        2.000000
# 50%             10.000000               3.000000        3.000000
# 75%             15.000000               3.000000        3.000000
# max             40.000000               6.000000        4.000000
#
#         YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# count      1470.000000        1470.000000              1470.000000
# unique             NaN                NaN                      NaN
# top                NaN                NaN                      NaN
# freq               NaN                NaN                      NaN
# mean          7.008163           4.229252                 2.187755
# std           6.126525           3.623137                 3.222430
# min           0.000000           0.000000                 0.000000
# 25%           3.000000           2.000000                 0.000000
# 50%           5.000000           3.000000                 1.000000
# 75%           9.000000           7.000000                 3.000000
# max          40.000000          18.000000                15.000000
#
#         YearsWithCurrManager
# count            1470.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean                4.123129
# std                 3.568136
# min                 0.000000
# 25%                 2.000000
# 50%                 3.000000
# 75%                 7.000000
# max                17.000000
#
# [11 rows x 35 columns]

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# # EDA:-

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Univariate Analysis:-

# %%
sns.countplot('Attrition',hue='Gender',data=df)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot('Age', hue='Attrition', data=df)
plt.show()

# %%
sns.countplot('JobSatisfaction', hue='Attrition', data=df)
plt.show()

# %%
sns.countplot('Department', hue='Attrition', data=df)
plt.show()

# %%
sns.countplot('Attrition', data=df)
plt.show()

# %% [markdown]
# We have Class Imbalance . We will Treat it in Further Steps.

# %%
sns.countplot('BusinessTravel', data=df)
plt.show()

# %%
sns.countplot('Department', data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot('EducationField', data=df)
plt.show()

# %%
sns.countplot('EnvironmentSatisfaction', data=df)
plt.show()

# %%
sns.countplot('Gender', data=df)
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
sns.countplot(y='JobRole', data=df)

# %%
sns.countplot('JobSatisfaction', data=df)
plt.show()

# %%
sns.countplot(y='EducationField', data=df)
plt.show()

# %% [markdown]
# # Bivariate Analysis:-

# %%
sns.scatterplot(x='Age', y='MonthlyIncome', data=df , color='orange')
plt.show()

# %%
sns.scatterplot(x='TotalWorkingYears', y='MonthlyIncome', data=df , color='black')
plt.show()

# %%
sns.countplot(y='EducationField', hue='Attrition', data=df)
plt.show()

# %%
pd.crosstab(df['Attrition'], df['EducationField'])
# Out:
# EducationField  Human Resources  Life Sciences  Marketing  Medical  Other  \
# Attrition
# No                           20            517        124      401     71
# Yes                           7             89         35       63     11
#
# EducationField  Technical Degree
# Attrition
# No                           100
# Yes                           32

# %%
pd.crosstab(df['Attrition'], df['JobSatisfaction'])
# Out:
# JobSatisfaction    1    2    3    4
# Attrition
# No               223  234  369  407
# Yes               66   46   73   52

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df )
plt.show()

# %%
sns.boxplot(x='Attrition', y='Age', data=df)
plt.show()

# %% [markdown]
# The attrition is more in age 32

# %%
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df)
plt.show()

# %% [markdown]
# Employee Staying in Far Away Places are leaving the company.

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Attrition'] = LE.fit_transform(df['Attrition'])

# %%
df['Attrition'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # Checking Correlation:-

# %%
corr=df.corr()

# %%
plt.figure(figsize=(22,12))
sns.heatmap(corr,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
corr['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# DistanceFromHome            0.077924
# NumCompaniesWorked          0.043494
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# YearsWithCurrManager       -0.156199
# Age                        -0.159205
# MonthlyIncome              -0.159840
# YearsInCurrentRole         -0.160545
# JobLevel                   -0.169105
# TotalWorkingYears          -0.171063
# EmployeeCount                    NaN
# StandardHours                    NaN
# Name: Attrition, dtype: float64

# %% [markdown]
# We can see that the attrition column is not correlated with any other column.

# %% [markdown]
# # Checking Skewness:-

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In our dataset there are 4 irrelevant columns so we will remove it.

# %%
df[['Over18', 'EmployeeCount', 'EmployeeNumber', 'StandardHours']].describe(include='all')
# Out:
#        Over18  EmployeeCount  EmployeeNumber  StandardHours
# count    1470         1470.0     1470.000000         1470.0
# unique      1            NaN             NaN            NaN
# top         Y            NaN             NaN            NaN
# freq     1470            NaN             NaN            NaN
# mean      NaN            1.0     1024.865306           80.0
# std       NaN            0.0      602.024335            0.0
# min       NaN            1.0        1.000000           80.0
# 25%       NaN            1.0      491.250000           80.0
# 50%       NaN            1.0     1020.500000           80.0
# 75%       NaN            1.0     1555.750000           80.0
# max       NaN            1.0     2068.000000           80.0

# %%
df.drop(['Over18', 'EmployeeCount', 'EmployeeNumber', 'StandardHours'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
df.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# JobSatisfaction          -0.004892  -0.103481   0.030571         -0.003669
# MonthlyIncome             0.497855  -0.159840   0.007707         -0.017014
# MonthlyRate               0.028051   0.015170  -0.032182          0.027473
# NumCompaniesWorked        0.299635   0.043494   0.038153         -0.029251
# PercentSalaryHike         0.003634  -0.013478   0.022704          0.040235
# PerformanceRating         0.001904   0.002889   0.000473          0.027110
# RelationshipSatisfaction  0.053535  -0.045872   0.007846          0.006557
# StockOptionLevel          0.037510  -0.137145   0.042143          0.044872
# TotalWorkingYears         0.680381  -0.171063   0.014515          0.004628
# TrainingTimesLastYear    -0.019621  -0.059478   0.002453         -0.036942
# WorkLifeBalance          -0.021490  -0.063939  -0.037848         -0.026556
# YearsAtCompany            0.311309  -0.134392  -0.034055          0.009508
# YearsInCurrentRole        0.212901  -0.160545   0.009932          0.018845
# YearsSinceLastPromotion   0.216513  -0.033019  -0.033229          0.010029
# YearsWithCurrManager      0.202089  -0.156199  -0.026363          0.014406
#
#                           Education  EnvironmentSatisfaction  HourlyRate  \
# Age                        0.208034                 0.010146    0.024287
# Attrition                 -0.031373                -0.103369   -0.006846
# DailyRate                 -0.016806                 0.018355    0.023381
# DistanceFromHome           0.021042                -0.016075    0.031131
# Education                  1.000000                -0.027128    0.016775
# EnvironmentSatisfaction   -0.027128                 1.000000   -0.049857
# HourlyRate                 0.016775                -0.049857    1.000000
# JobInvolvement             0.042438                -0.008278    0.042861
# JobLevel                   0.101589                 0.001212   -0.027853
# JobSatisfaction           -0.011296                -0.006784   -0.071335
# MonthlyIncome              0.094961                -0.006259   -0.015794
# MonthlyRate               -0.026084                 0.037600   -0.015297
# NumCompaniesWorked         0.126317                 0.012594    0.022157
# PercentSalaryHike         -0.011111                -0.031701   -0.009062
# PerformanceRating         -0.024539                -0.029548   -0.002172
# RelationshipSatisfaction  -0.009118                 0.007665    0.001330
# StockOptionLevel           0.018422                 0.003432    0.050263
# TotalWorkingYears          0.148280                -0.002693   -0.002334
# TrainingTimesLastYear     -0.025100                -0.019359   -0.008548
# WorkLifeBalance            0.009819                 0.027627   -0.004607
# YearsAtCompany             0.069114                 0.001458   -0.019582
# YearsInCurrentRole         0.060236                 0.018007   -0.024106
# YearsSinceLastPromotion    0.054254                 0.016194   -0.026716
# YearsWithCurrManager       0.069065                -0.004999   -0.020123
#
#                           JobInvolvement  JobLevel  JobSatisfaction  \
# Age                             0.029820  0.509604        -0.004892
# Attrition                      -0.130016 -0.169105        -0.103481
# DailyRate                       0.046135  0.002966         0.030571
# DistanceFromHome                0.008783  0.005303        -0.003669
# Education                       0.042438  0.101589        -0.011296
# EnvironmentSatisfaction        -0.008278  0.001212        -0.006784
# HourlyRate                      0.042861 -0.027853        -0.071335
# JobInvolvement                  1.000000 -0.012630        -0.021476
# JobLevel                       -0.012630  1.000000        -0.001944
# JobSatisfaction                -0.021476 -0.001944         1.000000
# MonthlyIncome                  -0.015271  0.950300        -0.007157
# MonthlyRate                    -0.016322  0.039563         0.000644
# NumCompaniesWorked              0.015012  0.142501        -0.055699
# PercentSalaryHike              -0.017205 -0.034730         0.020002
# PerformanceRating              -0.029071 -0.021222         0.002297
# RelationshipSatisfaction        0.034297  0.021642        -0.012454
# StockOptionLevel                0.021523  0.013984         0.010690
# TotalWorkingYears              -0.005533  0.782208        -0.020185
# TrainingTimesLastYear          -0.015338 -0.018191        -0.005779
# WorkLifeBalance                -0.014617  0.037818        -0.019459
# YearsAtCompany                 -0.021355  0.534739        -0.003803
# YearsInCurrentRole              0.008717  0.389447        -0.002305
# YearsSinceLastPromotion        -0.024184  0.353885        -0.018214
# YearsWithCurrManager            0.025976  0.375281        -0.027656
#
#                                   ...           PerformanceRating  \
# Age                               ...                    0.001904
# Attrition                         ...                    0.002889
# DailyRate                         ...                    0.000473
# DistanceFromHome                  ...                    0.027110
# Education                         ...                   -0.024539
# EnvironmentSatisfaction           ...                   -0.029548
# HourlyRate                        ...                   -0.002172
# JobInvolvement                    ...                   -0.029071
# JobLevel                          ...                   -0.021222
# JobSatisfaction                   ...                    0.002297
# MonthlyIncome                     ...                   -0.017120
# MonthlyRate                       ...                   -0.009811
# NumCompaniesWorked                ...                   -0.014095
# PercentSalaryHike                 ...                    0.773550
# PerformanceRating                 ...                    1.000000
# RelationshipSatisfaction          ...                   -0.031351
# StockOptionLevel                  ...                    0.003506
# TotalWorkingYears                 ...                    0.006744
# TrainingTimesLastYear             ...                   -0.015579
# WorkLifeBalance                   ...                    0.002572
# YearsAtCompany                    ...                    0.003435
# YearsInCurrentRole                ...                    0.034986
# YearsSinceLastPromotion           ...                    0.017896
# YearsWithCurrManager              ...                    0.022827
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.053535          0.037510
# Attrition                                -0.045872         -0.137145
# DailyRate                                 0.007846          0.042143
# DistanceFromHome                          0.006557          0.044872
# Education                                -0.009118          0.018422
# EnvironmentSatisfaction                   0.007665          0.003432
# HourlyRate                                0.001330          0.050263
# JobInvolvement                            0.034297          0.021523
# JobLevel                                  0.021642          0.013984
# JobSatisfaction                          -0.012454          0.010690
# MonthlyIncome                             0.025873          0.005408
# MonthlyRate                              -0.004085         -0.034323
# NumCompaniesWorked                        0.052733          0.030075
# PercentSalaryHike                        -0.040490          0.007528
# PerformanceRating                        -0.031351          0.003506
# RelationshipSatisfaction                  1.000000         -0.045952
# StockOptionLevel                         -0.045952          1.000000
# TotalWorkingYears                         0.024054          0.010136
# TrainingTimesLastYear                     0.002497          0.011274
# WorkLifeBalance                           0.019604          0.004129
# YearsAtCompany                            0.019367          0.015058
# YearsInCurrentRole                       -0.015123          0.050818
# YearsSinceLastPromotion                   0.033493          0.014352
# YearsWithCurrManager                     -0.000867          0.024698
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.680381              -0.019621
# Attrition                         -0.171063              -0.059478
# DailyRate                          0.014515               0.002453
# DistanceFromHome                   0.004628              -0.036942
# Education                          0.148280              -0.025100
# EnvironmentSatisfaction           -0.002693              -0.019359
# HourlyRate                        -0.002334              -0.008548
# JobInvolvement                    -0.005533              -0.015338
# JobLevel                           0.782208              -0.018191
# JobSatisfaction                   -0.020185              -0.005779
# MonthlyIncome                      0.772893              -0.021736
# MonthlyRate                        0.026442               0.001467
# NumCompaniesWorked                 0.237639              -0.066054
# PercentSalaryHike                 -0.020608              -0.005221
# PerformanceRating                  0.006744              -0.015579
# RelationshipSatisfaction           0.024054               0.002497
# StockOptionLevel                   0.010136               0.011274
# TotalWorkingYears                  1.000000              -0.035662
# TrainingTimesLastYear             -0.035662               1.000000
# WorkLifeBalance                    0.001008               0.028072
# YearsAtCompany                     0.628133               0.003569
# YearsInCurrentRole                 0.460365              -0.005738
# YearsSinceLastPromotion            0.404858              -0.002067
# YearsWithCurrManager               0.459188              -0.004096
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.021490        0.311309            0.212901
# Attrition                       -0.063939       -0.134392           -0.160545
# DailyRate                       -0.037848       -0.034055            0.009932
# DistanceFromHome                -0.026556        0.009508            0.018845
# Education                        0.009819        0.069114            0.060236
# EnvironmentSatisfaction          0.027627        0.001458            0.018007
# HourlyRate                      -0.004607       -0.019582           -0.024106
# JobInvolvement                  -0.014617       -0.021355            0.008717
# JobLevel                         0.037818        0.534739            0.389447
# JobSatisfaction                 -0.019459       -0.003803           -0.002305
# MonthlyIncome                    0.030683        0.514285            0.363818
# MonthlyRate                      0.007963       -0.023655           -0.012815
# NumCompaniesWorked              -0.008366       -0.118421           -0.090754
# PercentSalaryHike               -0.003280       -0.035991           -0.001520
# PerformanceRating                0.002572        0.003435            0.034986
# RelationshipSatisfaction         0.019604        0.019367           -0.015123
# StockOptionLevel                 0.004129        0.015058            0.050818
# TotalWorkingYears                0.001008        0.628133            0.460365
# TrainingTimesLastYear            0.028072        0.003569           -0.005738
# WorkLifeBalance                  1.000000        0.012089            0.049856
# YearsAtCompany                   0.012089        1.000000            0.758754
# YearsInCurrentRole               0.049856        0.758754            1.000000
# YearsSinceLastPromotion          0.008941        0.618409            0.548056
# YearsWithCurrManager             0.002759        0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# Attrition                               -0.033019             -0.156199
# DailyRate                               -0.033229             -0.026363
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EnvironmentSatisfaction                  0.016194             -0.004999
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobSatisfaction                         -0.018214             -0.027656
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [24 rows x 24 columns]

# %%
df[['MaritalStatus', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'OverTime']]
# Out:
#      MaritalStatus     BusinessTravel              Department  \
# 0           Single      Travel_Rarely                   Sales
# 1          Married  Travel_Frequently  Research & Development
# 2           Single      Travel_Rarely  Research & Development
# 3          Married  Travel_Frequently  Research & Development
# 4          Married      Travel_Rarely  Research & Development
# 5           Single  Travel_Frequently  Research & Development
# 6          Married      Travel_Rarely  Research & Development
# 7         Divorced      Travel_Rarely  Research & Development
# 8           Single  Travel_Frequently  Research & Development
# 9          Married      Travel_Rarely  Research & Development
# 10         Married      Travel_Rarely  Research & Development
# 11          Single      Travel_Rarely  Research & Development
# 12        Divorced      Travel_Rarely  Research & Development
# 13        Divorced      Travel_Rarely  Research & Development
# 14          Single      Travel_Rarely  Research & Development
# 15        Divorced      Travel_Rarely  Research & Development
# 16        Divorced      Travel_Rarely  Research & Development
# 17        Divorced         Non-Travel  Research & Development
# 18         Married      Travel_Rarely                   Sales
# 19          Single      Travel_Rarely  Research & Development
# 20        Divorced         Non-Travel  Research & Development
# 21          Single      Travel_Rarely                   Sales
# 22          Single      Travel_Rarely  Research & Development
# 23          Single      Travel_Rarely  Research & Development
# 24          Single      Travel_Rarely  Research & Development
# 25        Divorced      Travel_Rarely  Research & Development
# 26          Single  Travel_Frequently  Research & Development
# 27         Married      Travel_Rarely                   Sales
# 28         Married      Travel_Rarely  Research & Development
# 29          Single      Travel_Rarely                   Sales
# ...            ...                ...                     ...
# 1440      Divorced  Travel_Frequently  Research & Development
# 1441      Divorced         Non-Travel  Research & Development
# 1442       Married      Travel_Rarely  Research & Development
# 1443       Married      Travel_Rarely  Research & Development
# 1444       Married      Travel_Rarely  Research & Development
# 1445       Married      Travel_Rarely  Research & Development
# 1446       Married      Travel_Rarely                   Sales
# 1447      Divorced         Non-Travel                   Sales
# 1448      Divorced      Travel_Rarely                   Sales
# 1449        Single      Travel_Rarely  Research & Development
# 1450        Single      Travel_Rarely         Human Resources
# 1451       Married      Travel_Rarely                   Sales
# 1452      Divorced  Travel_Frequently                   Sales
# 1453       Married      Travel_Rarely                   Sales
# 1454        Single      Travel_Rarely                   Sales
# 1455        Single      Travel_Rarely  Research & Development
# 1456       Married  Travel_Frequently  Research & Development
# 1457       Married      Travel_Rarely  Research & Development
# 1458       Married      Travel_Rarely  Research & Development
# 1459       Married      Travel_Rarely  Research & Development
# 1460        Single      Travel_Rarely  Research & Development
# 1461      Divorced      Travel_Rarely                   Sales
# 1462       Married      Travel_Rarely                   Sales
# 1463        Single         Non-Travel  Research & Development
# 1464        Single      Travel_Rarely                   Sales
# 1465       Married  Travel_Frequently  Research & Development
# 1466       Married      Travel_Rarely  Research & Development
# 1467       Married      Travel_Rarely  Research & Development
# 1468       Married  Travel_Frequently                   Sales
# 1469       Married      Travel_Rarely  Research & Development
#
#         EducationField  Gender                    JobRole OverTime
# 0        Life Sciences  Female            Sales Executive      Yes
# 1        Life Sciences    Male         Research Scientist       No
# 2                Other    Male      Laboratory Technician      Yes
# 3        Life Sciences  Female         Research Scientist      Yes
# 4              Medical    Male      Laboratory Technician       No
# 5        Life Sciences    Male      Laboratory Technician       No
# 6              Medical  Female      Laboratory Technician      Yes
# 7        Life Sciences    Male      Laboratory Technician       No
# 8        Life Sciences    Male     Manufacturing Director       No
# 9              Medical    Male  Healthcare Representative       No
# 10             Medical    Male      Laboratory Technician       No
# 11       Life Sciences  Female      Laboratory Technician      Yes
# 12       Life Sciences    Male         Research Scientist       No
# 13             Medical    Male      Laboratory Technician       No
# 14       Life Sciences    Male      Laboratory Technician      Yes
# 15       Life Sciences  Female     Manufacturing Director       No
# 16       Life Sciences    Male         Research Scientist      Yes
# 17             Medical    Male      Laboratory Technician      Yes
# 18       Life Sciences  Female                    Manager       No
# 19       Life Sciences    Male         Research Scientist      Yes
# 20               Other  Female     Manufacturing Director       No
# 21       Life Sciences    Male       Sales Representative       No
# 22       Life Sciences  Female          Research Director       No
# 23       Life Sciences    Male         Research Scientist       No
# 24             Medical    Male         Research Scientist       No
# 25               Other  Female                    Manager       No
# 26       Life Sciences  Female         Research Scientist      Yes
# 27           Marketing    Male            Sales Executive       No
# 28             Medical  Female  Healthcare Representative       No
# 29           Marketing  Female                    Manager       No
# ...                ...     ...                        ...      ...
# 1440     Life Sciences  Female     Manufacturing Director       No
# 1441     Life Sciences    Male  Healthcare Representative       No
# 1442           Medical    Male         Research Scientist      Yes
# 1443     Life Sciences    Male                    Manager       No
# 1444  Technical Degree    Male      Laboratory Technician       No
# 1445     Life Sciences  Female     Manufacturing Director       No
# 1446         Marketing  Female            Sales Executive       No
# 1447         Marketing    Male            Sales Executive       No
# 1448     Life Sciences    Male            Sales Executive       No
# 1449  Technical Degree    Male         Research Scientist       No
# 1450     Life Sciences  Female            Human Resources      Yes
# 1451     Life Sciences  Female            Sales Executive       No
# 1452     Life Sciences    Male            Sales Executive       No
# 1453         Marketing  Female            Sales Executive       No
# 1454     Life Sciences  Female            Sales Executive       No
# 1455     Life Sciences    Male         Research Scientist       No
# 1456     Life Sciences    Male  Healthcare Representative      Yes
# 1457           Medical  Female         Research Scientist       No
# 1458     Life Sciences  Female         Research Scientist       No
# 1459             Other    Male      Laboratory Technician      Yes
# 1460           Medical  Female         Research Scientist       No
# 1461         Marketing    Male            Sales Executive      Yes
# 1462         Marketing  Female            Sales Executive       No
# 1463           Medical    Male     Manufacturing Director       No
# 1464             Other  Female       Sales Representative       No
# 1465           Medical    Male      Laboratory Technician       No
# 1466           Medical    Male  Healthcare Representative       No
# 1467     Life Sciences    Male     Manufacturing Director      Yes
# 1468           Medical    Male            Sales Executive       No
# 1469           Medical    Male      Laboratory Technician       No
#
# [1470 rows x 7 columns]

# %%
MaritalStatus = pd.get_dummies(df['MaritalStatus'])
BusinessTravel = pd.get_dummies(df['BusinessTravel'])
Department = pd.get_dummies(df['Department'])
EducationField = pd.get_dummies(df['EducationField'])
Gender = pd.get_dummies(df['Gender'])
JobRole = pd.get_dummies(df['JobRole'])
OverTime = pd.get_dummies(df['OverTime'])

# %%
merged = pd.concat([df, MaritalStatus, BusinessTravel, Department, EducationField, Gender, JobRole, OverTime], axis='columns')

# %%
merged.drop(['MaritalStatus', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'OverTime'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
merged.shape
# Out:
# (1470, 52)

# %% [markdown]
# Now we will Balance Our Target Variable.

# %%
x=merged.drop('Attrition',axis=1)
y=merged['Attrition']

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

smote = SMOTE()

x = np.array(x)
# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(x, y.ravel())

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_smote))
# Out:
# Original dataset shape Counter({0: 1233, 1: 237})
# Resample dataset shape Counter({1: 1233, 0: 1233})

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import sklearn.metrics as metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Finding Best Random State.

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size=0.33, random_state=i)
    lg = LogisticRegression()
    lg.fit(x_train, y_train)
    pred = lg.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is: ",maxAccu,"on Random State: ",maxRS)
# Out:
# Best accuracy is:  0.7764127764127764 on Random State:  40

# %% [markdown]
# We have found our best random state 40 . Now we will create train_test_split using random state 40.

# %% [markdown]
# # Creating train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.3,random_state=40)

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
pred = lr.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print('f1_Score:', f1_score(y_test, pred))
# Out:
# Accuracy Score: 0.7621621621621621
# [[283  99]
#  [ 77 281]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       382
#            1       0.74      0.78      0.76       358
#
#     accuracy                           0.76       740
#    macro avg       0.76      0.76      0.76       740
# weighted avg       0.76      0.76      0.76       740
#
# f1_Score: 0.7615176151761518

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
pred = knn.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print('f1_Score:', f1_score(y_test, pred))
# Out:
# Accuracy Score: 0.7567567567567568
# [[247 135]
#  [ 45 313]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.65      0.73       382
#            1       0.70      0.87      0.78       358
#
#     accuracy                           0.76       740
#    macro avg       0.77      0.76      0.75       740
# weighted avg       0.77      0.76      0.75       740
#
# f1_Score: 0.7766749379652605

# %%
svc = SVC()
svc.fit(x_train, y_train)
pred = svc.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print('f1_Score:', f1_score(y_test, pred))
# Out:
# Accuracy Score: 0.6189189189189189
# [[195 187]
#  [ 95 263]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.51      0.58       382
#            1       0.58      0.73      0.65       358
#
#     accuracy                           0.62       740
#    macro avg       0.63      0.62      0.62       740
# weighted avg       0.63      0.62      0.61       740
#
# f1_Score: 0.650990099009901

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
pred = gnb.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print('f1_Score:', f1_score(y_test, pred))
# Out:
# Accuracy Score: 0.8175675675675675
# [[273 109]
#  [ 26 332]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80       382
#            1       0.75      0.93      0.83       358
#
#     accuracy                           0.82       740
#    macro avg       0.83      0.82      0.82       740
# weighted avg       0.84      0.82      0.82       740
#
# f1_Score: 0.8310387984981227

# %% [markdown]
# # Checking the Cross Val Score:-

# %%
scr = cross_val_score(lr, x, y, cv=5)
print('Cross validation score for Logistic regression:',scr.mean()*100)
# Out:
# Cross validation score for Logistic regression: 84.21768707482993

# %%
scr = cross_val_score(knn, x, y, cv=5)
print('Cross validation score for K Nearest Neighbors:', scr.mean()*100)
# Out:
# Cross validation score for K Nearest Neighbors: 82.85714285714286

# %%
scr = cross_val_score(svc, x, y, cv=5)
print('Cross validation score for SVC:', scr.mean()*100)
# Out:
# Cross validation score for SVC: 83.87755102040816

# %%
scr = cross_val_score(gnb, x, y, cv=5)
print('Cross validation score for GaussianNB:', scr.mean()*100)
# Out:
# Cross validation score for GaussianNB: 77.21088435374149

# %% [markdown]
# Logistic Regression is Selected because it has the highest cross val score.

# %% [markdown]
# # Hyper Parameter Tuning.

# %%
penalty = ['l1', 'l2', 'elasticnet', 'none']
fit_intercept = ['True', 'False']
solver = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
multi_class = ['auto', 'ovr', 'multinomial']
C = np.logspace(-5, 8, 15)

params = {'penalty' : penalty,
         'fit_intercept' : fit_intercept,
         'solver' : solver,
         'multi_class' : multi_class,
         'C' : C}

# %%
from sklearn.model_selection import GridSearchCV

# %%
GCV = GridSearchCV(LogisticRegression(), params, cv=5)
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': array([1.00000000e-05, 8.48342898e-05, 7.19685673e-04, 6.10540230e-03,
#        5.17947468e-02, 4.39397056e-01, 3.72759372e+00, 3.16227766e+01,
#        2.68269580e+02, 2.27584593e+03, 1.93069773e+04, 1.63789371e+05,
#        1.38949549e+06, 1.17876863e+07, 1.00000000e+08]),
#                          'fit_intercept': ['True', 'False'],
#                          'multi_class': ['auto', 'ovr', 'multinomial'],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']})

# %%
GCV.best_params_
# Out:
# {'C': 2275.845926074791,
#  'fit_intercept': 'False',
#  'multi_class': 'ovr',
#  'penalty': 'l1',
#  'solver': 'liblinear'}

# %%
model = LogisticRegression(C=1389495.494373136, fit_intercept='True', multi_class='ovr', penalty='l1', solver='liblinear')
model.fit(x_train, y_train)
modpred = model.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, modpred))
print(confusion_matrix(y_test, modpred))
print(classification_report(y_test, modpred))
print('f1_Score:', f1_score(y_test, modpred)*100)
# Out:
# Accuracy Score: 0.9324324324324325
# [[368  14]
#  [ 36 322]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       382
#            1       0.96      0.90      0.93       358
#
#     accuracy                           0.93       740
#    macro avg       0.93      0.93      0.93       740
# weighted avg       0.93      0.93      0.93       740
#
# f1_Score: 92.79538904899135

# %% [markdown]
# # Plotting The ROC-AUC Curve

# %%
# calculate the fpr and tpr for all thresholds of the classification

probs = model.predict_proba(x_test)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# plotting
plt.title('Receiver Operating Characteristics')
plt.plot(fpr, tpr, 'b', label='AUC = %0.2f' % roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# # Checking our Predictions:-

# %%
predictions = pd.DataFrame({'Predictions':modpred,'Real Values':y_test})

# %%
predictions
# Out:
#      Predictions  Real Values
# 0              0            0
# 1              1            1
# 2              1            1
# 3              0            0
# 4              0            0
# 5              0            0
# 6              1            1
# 7              0            0
# 8              0            0
# 9              1            1
# 10             1            1
# 11             1            1
# 12             1            1
# 13             0            0
# 14             0            0
# 15             0            0
# 16             1            1
# 17             0            0
# 18             0            0
# 19             0            0
# 20             0            0
# 21             0            0
# 22             0            0
# 23             1            1
# 24             0            0
# 25             1            1
# 26             1            1
# 27             1            1
# 28             1            1
# 29             1            1
# ..           ...          ...
# 710            0            0
# 711            1            1
# 712            0            1
# 713            1            1
# 714            0            0
# 715            0            0
# 716            0            0
# 717            0            1
# 718            0            0
# 719            0            0
# 720            0            0
# 721            0            0
# 722            0            0
# 723            1            1
# 724            1            1
# 725            1            1
# 726            1            1
# 727            1            1
# 728            1            1
# 729            1            1
# 730            0            0
# 731            1            1
# 732            1            1
# 733            1            1
# 734            0            0
# 735            1            1
# 736            0            0
# 737            0            0
# 738            0            0
# 739            1            1
#
# [740 rows x 2 columns]

# %% [markdown]
# # Saving the Model:-

# %%
import joblib
joblib.dump(model, 'HRmodel.pkl')
# Out:
# ['HRmodel.pkl']

# %% [markdown]
# # Loading the Saved Model

# %%
saved_model = joblib.load('HRmodel.pkl')
prediction = model.predict(x_test)
print(f1_score(y_test, prediction)*100)
# Out:
# 92.79538904899135
